# %% [markdown]
# ""Exercicio 01""

# %%
print('Olá Mundo, meu nome é Clara')
# Out:
# Olá Mundo, meu nome é Clara

# %% [markdown]
# ""Exercicio 02""

# %%
print('Meu nome é Clara.')
# Out:
# Meu nome é Clara.

# %%
print ('Meu Ra é 3011542623010.')
# Out:
# Meu Ra é 3011542623010.

# %%
print ('Escolhi esse curso porque quero tabalhar com dados.')
# Out:
# Escolhi esse curso porque quero tabalhar com dados.

# %% [markdown]
# ""Exercicio 03""
# Meu nome é Clara. Estou começamdo a estudar programação.
# Quero aprender a transformar problemas em instruções para o computador.

# %%
print ('Essa é minha primeira mensagem executada em Python.')
# Out:
# Essa é minha primeira mensagem executada em Python.

# %% [markdown]
# ""Exercicio 04""

# %%
print ('Nome: Jaqueline Clara')
print ('Curso: Ciência de Dados para Negócios')
print ('Disciplina: Algoritmos e Programção com AI')
print ('Meta: aprender a resolver problemas com programção')
# Out:
# Nome: Jaqueline Clara
# Curso: Ciência de Dados para Negócios
# Disciplina: Algoritmos e Programção com AI
# Meta: aprender a resolver problemas com programção

# %% [markdown]
# ""Exercicio 05""

# %%
print ('Sistema de Vendas CDN')
print ('Bem-vindos ao painel inicial.')
print ('Os dados de vendas ainda serão carregados.')
print ('aguarde a próxima etapa para iniciar a análise.')
# Out:
# Sistema de Vendas CDN
# Bem-vindos ao painel inicial.
# Os dados de vendas ainda serão carregados.
# aguarde a próxima etapa para iniciar a análise.

# %% [markdown]
# ""Exercicio 06""

# %%
print ('Notebook de estudos - Algoritmos e programação de IA')
print ("Semana I - Introduçaõ ao ambiente de programação.")
# Out:
# Notebook de estudos - Algoritmos e programação de IA
# Semana I - Introduçaõ ao ambiente de programação.

# %%
print ('Oi! Este é o meu primeiro notebook de Python.')
print ('Ainda estou aprendendo, mas já estou conseguindo executar código!')
# Out:
# Oi! Este é o meu primeiro notebook de Python.
# Ainda estou aprendendo, mas já estou conseguindo executar código!

# %%
print ('Notebook: Cap01_JaquelineClara.ipynb')
print ('Abiente: Google Colab | Linguagem: Python')
# Out:
# Notebook: Cap01_JaquelineClara.ipynb
# Abiente: Google Colab | Linguagem: Python

# %% [markdown]
# ""Exercicio 07""
# O que aconteceu, foi de não ter inserido os dois '' no inicio e no fim, contudo o código não pode ser executado, ele precisa estar escrito 100% correto para que seja executado.

# %%
print (Olá Mundo!)
# Out:
#   File "/tmp/ipykernel_3317/3893230670.py", line 1
#     print (Olá Mundo!)
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ""Exercicio 08""
# O que aconteceu, foi de não ter inserido o ' no fim da frase, o código não pode ser executado se não estiver escrito de maneira 100% correta.

# %%
print('Bem-vindo ao curso)
# Out:
#   File "/tmp/ipykernel_3317/1022686157.py", line 1
#     print('Bem-vindo ao curso)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# ""Exercicio 09""
# O que aconteceu foi de ter escrito na célula errada. Era para ser a de Código mas foi escrito na de Texto, contudo não será executada nenhum comando por conta desse erro.

# %% [markdown]
# print ("Teste")

# %% [markdown]
# ""Exercicio 10""

# %%
print('Nome: Jaqueline Clara')
print ('Curso: Ciência de Dados para Negócios')
print ('Disciplina: Algoritmos e Programação de IA')
print ('Habilidade que quero desenvolver: resolver problemas com código Python')
print ('Sobre IA: vou usar para usar estudar, mas sempre vou testar e explicar o código.')
# Out:
# Nome: Jaqueline Clara
# Curso: Ciência de Dados para Negócios
# Disciplina: Algoritmos e Programação de IA
# Habilidade que quero desenvolver: resolver problemas com código Python
# Sobre IA: vou usar para usar estudar, mas sempre vou testar e explicar o código.

# %% [markdown]
# ""Exercício 11""
